# %%
from google.colab import drive
drive.mount('/content/drive')
# %run /content/drive/My\ Drive/code/test.py
# Out:
# Mounted at /content/drive
# Namespace(batch_size=16, batch_size_index=1, batch_size_test=1, beta1=0.9, beta2=0.99, case_test='d10-d8', case_train='case5', d_steps=1, epochs=300, g_steps=1, image_H=256, image_W=256, image_channels=3, image_show_interval=30, image_store_interval=30, lambda_gp=10, latent_dim=128, loss_show_interval=20, losses_root='/content/drive/My Drive/code/losses', lr=0.0002, method='/dualGAN/', mode_save_interval=50, model_root='/content/drive/My Drive/code/model', n_classes=10, ndf=64, ngf=64, noise_dimension=16, premodel=1, test_root='/content/drive/My Drive/code/facades/test/case5', train_root='/content/drive/My Drive/code/facades/train')
# ...
